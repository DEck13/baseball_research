# %%
import pandas as pd

# %%
target = pd.read_csv("MC2015.csv")
league = pd.read_csv("MLB2015.csv")
injury_date = (7.04,)
recovered_date = (8.12,)
strong_start = (6.17,)
strong_end = (7.30,)
min_to_be_Strong = 86
min_to_be_Average = 77

# %%
target = target[['Date', 'Tm', 'Opp', 'W/L']]
league = league[['Tm', 'W']]
league =league.rename(columns={'Tm' : 'Opp'})
df = pd.merge(target, league, on = 'Opp')

# %%
target
# Out:
#                   Date   Tm  Opp   W/L
# 0         Monday Apr 6  DET  MIN     W
# 1      Wednesday Apr 8  DET  MIN     W
# 2       Thursday Apr 9  DET  MIN     W
# 3        Friday Apr 10  DET  CLE     W
# 4      Saturday Apr 11  DET  CLE     W
# 5        Sunday Apr 12  DET  CLE     W
# 6        Monday Apr 13  DET  PIT     L
# 7       Tuesday Apr 14  DET  PIT     W
# 8     Wednesday Apr 15  DET  PIT     W
# 9        Friday Apr 17  DET  CHW  W-wo
# 10     Saturday Apr 18  DET  CHW     L
# 11       Sunday Apr 19  DET  CHW     W
# 12       Monday Apr 20  DET  NYY     W
# 13      Tuesday Apr 21  DET  NYY     L
# 14    Wednesday Apr 22  DET  NYY     L
# 15     Thursday Apr 23  DET  NYY     L
# 16       Friday Apr 24  DET  CLE     L
# 17     Saturday Apr 25  DET  CLE     W
# 18       Sunday Apr 26  DET  CLE     W
# 19       Monday Apr 27  DET  MIN     W
# 20      Tuesday Apr 28  DET  MIN     L
# 21    Wednesday Apr 29  DET  MIN     W
# 22     Thursday Apr 30  DET  KCR     L
# 23        Friday May 1  DET  KCR     L
# 24      Saturday May 2  DET  KCR     W
# 25        Sunday May 3  DET  KCR     W
# 26       Tuesday May 5  DET  CHW     L
# 27     Wednesday May 6  DET  CHW     L
# 28      Thursday May 7  DET  CHW     W
# 29        Friday May 8  DET  KCR  W-wo
# ..                 ...  ...  ...   ...
# 131    Wednesday Sep 2  DET  KCR     L
# 132     Thursday Sep 3  DET  KCR     L
# 133       Friday Sep 4  DET  CLE     L
# 134     Saturday Sep 5  DET  CLE     W
# 135       Sunday Sep 6  DET  CLE     L
# 136       Monday Sep 7  DET  TBR     W
# 137      Tuesday Sep 8  DET  TBR  W-wo
# 138    Wednesday Sep 9  DET  TBR     L
# 139    Thursday Sep 10  DET  CLE     L
# 140  Sunday Sep 13 (1)  DET  CLE     L
# 141  Sunday Sep 13 (2)  DET  CLE     W
# 142      Monday Sep 14  DET  MIN     L
# 143     Tuesday Sep 15  DET  MIN     W
# 144   Wednesday Sep 16  DET  MIN     W
# 145      Friday Sep 18  DET  KCR  W-wo
# 146    Saturday Sep 19  DET  KCR  W-wo
# 147      Sunday Sep 20  DET  KCR     L
# 148  Monday Sep 21 (1)  DET  CHW     L
# 149  Monday Sep 21 (2)  DET  CHW     L
# 150     Tuesday Sep 22  DET  CHW  W-wo
# 151   Wednesday Sep 23  DET  CHW     W
# 152      Friday Sep 25  DET  MIN     W
# 153    Saturday Sep 26  DET  MIN     L
# 154      Sunday Sep 27  DET  MIN     L
# 155      Monday Sep 28  DET  TEX     W
# 156     Tuesday Sep 29  DET  TEX     L
# 157   Wednesday Sep 30  DET  TEX     L
# 158       Friday Oct 2  DET  CHW     L
# 159     Saturday Oct 3  DET  CHW  L-wo
# 160       Sunday Oct 4  DET  CHW     W
#
# [161 rows x 4 columns]

# %%
league
# Out:
#       Opp    W
# 0     ARI   79
# 1     ATL   67
# 2     BAL   81
# 3     BOS   78
# 4     CHC   97
# 5     CHW   76
# 6     CIN   64
# 7     CLE   81
# 8     COL   68
# 9     DET   74
# 10    HOU   86
# 11    KCR   95
# 12    LAA   85
# 13    LAD   92
# 14    MIA   71
# 15    MIL   68
# 16    MIN   83
# 17    NYM   90
# 18    NYY   87
# 19    OAK   68
# 20    PHI   63
# 21    PIT   98
# 22    SDP   74
# 23    SEA   76
# 24    SFG   84
# 25    STL  100
# 26    TBR   80
# 27    TEX   88
# 28    TOR   93
# 29    WSN   83
# 30  LgAvg   81

# %%
df
# Out:
#                  Date   Tm  Opp   W/L   W
# 0        Monday Apr 6  DET  MIN     W  83
# 1     Wednesday Apr 8  DET  MIN     W  83
# 2      Thursday Apr 9  DET  MIN     W  83
# 3       Monday Apr 27  DET  MIN     W  83
# 4      Tuesday Apr 28  DET  MIN     L  83
# 5    Wednesday Apr 29  DET  MIN     W  83
# 6      Tuesday May 12  DET  MIN  W-wo  83
# 7    Wednesday May 13  DET  MIN     L  83
# 8     Thursday May 14  DET  MIN     W  83
# 9      Thursday Jul 9  DET  MIN     W  83
# 10      Friday Jul 10  DET  MIN  L-wo  83
# 11    Saturday Jul 11  DET  MIN     L  83
# 12      Sunday Jul 12  DET  MIN     L  83
# 13      Monday Sep 14  DET  MIN     L  83
# 14     Tuesday Sep 15  DET  MIN     W  83
# 15   Wednesday Sep 16  DET  MIN     W  83
# 16      Friday Sep 25  DET  MIN     W  83
# 17    Saturday Sep 26  DET  MIN     L  83
# 18      Sunday Sep 27  DET  MIN     L  83
# 19      Friday Apr 10  DET  CLE     W  81
# 20    Saturday Apr 11  DET  CLE     W  81
# 21      Sunday Apr 12  DET  CLE     W  81
# 22      Friday Apr 24  DET  CLE     L  81
# 23    Saturday Apr 25  DET  CLE     W  81
# 24      Sunday Apr 26  DET  CLE     W  81
# 25      Friday Jun 12  DET  CLE     W  81
# 26    Saturday Jun 13  DET  CLE     L  81
# 27      Sunday Jun 14  DET  CLE     W  81
# 28      Monday Jun 22  DET  CLE     W  81
# 29     Tuesday Jun 23  DET  CLE     W  81
# ..                ...  ...  ...   ...  ..
# 131     Monday Jul 20  DET  SEA     W  76
# 132    Tuesday Jul 21  DET  SEA     L  76
# 133  Wednesday Jul 22  DET  SEA     W  76
# 134   Thursday Jul 23  DET  SEA     L  76
# 135     Friday Jul 17  DET  BAL     W  81
# 136   Saturday Jul 18  DET  BAL     L  81
# 137     Sunday Jul 19  DET  BAL     L  81
# 138   Thursday Jul 30  DET  BAL     W  81
# 139     Friday Jul 31  DET  BAL     L  81
# 140    Saturday Aug 1  DET  BAL     L  81
# 141      Sunday Aug 2  DET  BAL     W  81
# 142     Friday Jul 24  DET  BOS  L-wo  78
# 143   Saturday Jul 25  DET  BOS     W  78
# 144     Sunday Jul 26  DET  BOS     L  78
# 145      Friday Aug 7  DET  BOS     L  78
# 146    Saturday Aug 8  DET  BOS     W  78
# 147      Sunday Aug 9  DET  BOS     L  78
# 148     Monday Jul 27  DET  TBR     L  80
# 149    Tuesday Jul 28  DET  TBR     L  80
# 150  Wednesday Jul 29  DET  TBR     W  80
# 151      Monday Sep 7  DET  TBR     W  80
# 152     Tuesday Sep 8  DET  TBR  W-wo  80
# 153   Wednesday Sep 9  DET  TBR     L  80
# 154   Thursday Aug 20  DET  TEX     W  88
# 155     Friday Aug 21  DET  TEX     L  88
# 156   Saturday Aug 22  DET  TEX     L  88
# 157     Sunday Aug 23  DET  TEX     L  88
# 158     Monday Sep 28  DET  TEX     W  88
# 159    Tuesday Sep 29  DET  TEX     L  88
# 160  Wednesday Sep 30  DET  TEX     L  88
#
# [161 rows x 5 columns]

# %%
#helper function to modify the date data for later analysis
def modi_date(date):
    date_dict = {
        'Mar': '3',
        'Apr': '4',
        'May': '5',
        'Jun': '6',
        'Jul': '7',
        'Aug': '8',
        'Sep': '9',
        'Oct': '10'
    }
    date_split = date.split(" ")[1:]
    d = date_dict[date_split[0]]
    return float('{}.{:0>2}'.format(date_dict[date_split[0]], date_split[1]))

# %%
df['Date'] = df['Date'].apply(modi_date)
df = df.sort_values(by = ['Date'])

# %%
df
# Out:
#       Date   Tm  Opp   W/L   W
# 0     4.06  DET  MIN     W  83
# 1     4.08  DET  MIN     W  83
# 2     4.09  DET  MIN     W  83
# 19    4.10  DET  CLE     W  81
# 20    4.11  DET  CLE     W  81
# 21    4.12  DET  CLE     W  81
# 37    4.13  DET  PIT     L  98
# 38    4.14  DET  PIT     W  98
# 39    4.15  DET  PIT     W  98
# 43    4.17  DET  CHW  W-wo  76
# 44    4.18  DET  CHW     L  76
# 45    4.19  DET  CHW     W  76
# 62    4.20  DET  NYY     W  87
# 63    4.21  DET  NYY     L  87
# 64    4.22  DET  NYY     L  87
# 65    4.23  DET  NYY     L  87
# 22    4.24  DET  CLE     L  81
# 23    4.25  DET  CLE     W  81
# 24    4.26  DET  CLE     W  81
# 3     4.27  DET  MIN     W  83
# 4     4.28  DET  MIN     L  83
# 5     4.29  DET  MIN     W  83
# 69    4.30  DET  KCR     L  95
# 70    5.01  DET  KCR     L  95
# 71    5.02  DET  KCR     W  95
# 72    5.03  DET  KCR     W  95
# 46    5.05  DET  CHW     L  76
# 47    5.06  DET  CHW     L  76
# 48    5.07  DET  CHW     W  76
# 73    5.08  DET  KCR  W-wo  95
# ..     ...  ...  ...   ...  ..
# 83    9.02  DET  KCR     L  95
# 84    9.03  DET  KCR     L  95
# 31    9.04  DET  CLE     L  81
# 32    9.05  DET  CLE     W  81
# 33    9.06  DET  CLE     L  81
# 151   9.07  DET  TBR     W  80
# 152   9.08  DET  TBR  W-wo  80
# 153   9.09  DET  TBR     L  80
# 34    9.10  DET  CLE     L  81
# 36    9.13  DET  CLE     W  81
# 35    9.13  DET  CLE     L  81
# 13    9.14  DET  MIN     L  83
# 14    9.15  DET  MIN     W  83
# 15    9.16  DET  MIN     W  83
# 85    9.18  DET  KCR  W-wo  95
# 86    9.19  DET  KCR  W-wo  95
# 87    9.20  DET  KCR     L  95
# 56    9.21  DET  CHW     L  76
# 55    9.21  DET  CHW     L  76
# 57    9.22  DET  CHW  W-wo  76
# 58    9.23  DET  CHW     W  76
# 16    9.25  DET  MIN     W  83
# 17    9.26  DET  MIN     L  83
# 18    9.27  DET  MIN     L  83
# 158   9.28  DET  TEX     W  88
# 159   9.29  DET  TEX     L  88
# 160   9.30  DET  TEX     L  88
# 59   10.02  DET  CHW     L  76
# 60   10.03  DET  CHW  L-wo  76
# 61   10.04  DET  CHW     W  76
#
# [161 rows x 5 columns]

# %%
def get_winning_games_number(team_name: str):
    return league[league['Opp'] == team_name]['W'].values[0]

# %%
#helper function to get the classify an opponent's status: weak, average, or strong
def get_oppo_status(team_name: str):
    w_n = get_winning_games_number(team_name)
    if w_n >= min_to_be_Strong:
        return "Strong"
    elif min_to_be_Average <= w_n < min_to_be_Strong:
        return 'Average'
    else:
        return "Weak"

# %%
def get_avaliablity(date):
    for inj, rec in zip(injury_date, recovered_date):
        if inj <= date <= rec:
            return False
    return True

# %%
def is_Strong(date):
    for start, end in zip(strong_start, strong_end):
        if start <= date < end:
            return True
    return False

# %%
frame = pd.DataFrame({
                      'Date': df['Date'], 
                      "Aval": df['Date'].apply(get_avaliablity), 
                      "Strong": df['Date'].apply(is_Strong),
                      "Opp-Status": df['Opp'].apply(get_oppo_status),
                      'Opp': df['Opp'],
                      'W/L': df['W/L'], 
                      'Opp-W': df['W']
                      })

# %%
frame
# Out:
#       Date  Aval  Strong Opp-Status  Opp   W/L  Opp-W
# 0     4.06  True   False    Average  MIN     W     83
# 1     4.08  True   False    Average  MIN     W     83
# 2     4.09  True   False    Average  MIN     W     83
# 19    4.10  True   False       Weak  CLE     W     81
# 20    4.11  True   False       Weak  CLE     W     81
# 21    4.12  True   False       Weak  CLE     W     81
# 37    4.13  True   False     Strong  PIT     L     98
# 38    4.14  True   False     Strong  PIT     W     98
# 39    4.15  True   False     Strong  PIT     W     98
# 43    4.17  True   False       Weak  CHW  W-wo     76
# 44    4.18  True   False       Weak  CHW     L     76
# 45    4.19  True   False       Weak  CHW     W     76
# 62    4.20  True   False    Average  NYY     W     87
# 63    4.21  True   False    Average  NYY     L     87
# 64    4.22  True   False    Average  NYY     L     87
# 65    4.23  True   False    Average  NYY     L     87
# 22    4.24  True   False       Weak  CLE     L     81
# 23    4.25  True   False       Weak  CLE     W     81
# 24    4.26  True   False       Weak  CLE     W     81
# 3     4.27  True   False    Average  MIN     W     83
# 4     4.28  True   False    Average  MIN     L     83
# 5     4.29  True   False    Average  MIN     W     83
# 69    4.30  True   False     Strong  KCR     L     95
# 70    5.01  True   False     Strong  KCR     L     95
# 71    5.02  True   False     Strong  KCR     W     95
# 72    5.03  True   False     Strong  KCR     W     95
# 46    5.05  True   False       Weak  CHW     L     76
# 47    5.06  True   False       Weak  CHW     L     76
# 48    5.07  True   False       Weak  CHW     W     76
# 73    5.08  True   False     Strong  KCR  W-wo     95
# ..     ...   ...     ...        ...  ...   ...    ...
# 83    9.02  True   False     Strong  KCR     L     95
# 84    9.03  True   False     Strong  KCR     L     95
# 31    9.04  True   False       Weak  CLE     L     81
# 32    9.05  True   False       Weak  CLE     W     81
# 33    9.06  True   False       Weak  CLE     L     81
# 151   9.07  True   False       Weak  TBR     W     80
# 152   9.08  True   False       Weak  TBR  W-wo     80
# 153   9.09  True   False       Weak  TBR     L     80
# 34    9.10  True   False       Weak  CLE     L     81
# 36    9.13  True   False       Weak  CLE     W     81
# 35    9.13  True   False       Weak  CLE     L     81
# 13    9.14  True   False    Average  MIN     L     83
# 14    9.15  True   False    Average  MIN     W     83
# 15    9.16  True   False    Average  MIN     W     83
# 85    9.18  True   False     Strong  KCR  W-wo     95
# 86    9.19  True   False     Strong  KCR  W-wo     95
# 87    9.20  True   False     Strong  KCR     L     95
# 56    9.21  True   False       Weak  CHW     L     76
# 55    9.21  True   False       Weak  CHW     L     76
# 57    9.22  True   False       Weak  CHW  W-wo     76
# 58    9.23  True   False       Weak  CHW     W     76
# 16    9.25  True   False    Average  MIN     W     83
# 17    9.26  True   False    Average  MIN     L     83
# 18    9.27  True   False    Average  MIN     L     83
# 158   9.28  True   False    Average  TEX     W     88
# 159   9.29  True   False    Average  TEX     L     88
# 160   9.30  True   False    Average  TEX     L     88
# 59   10.02  True   False       Weak  CHW     L     76
# 60   10.03  True   False       Weak  CHW  L-wo     76
# 61   10.04  True   False       Weak  CHW     W     76
#
# [161 rows x 7 columns]

# %%
frame.to_csv('Miguel_Cabrera_2015.csv')

# %%
#helper funtion to calculate the number of the games in which the target team and its
#opponent are classifies as a particular status.
def count_category(data, strong=False, opp_status=None):
    strong_series = data['Strong'] if strong else data['Strong'] == False
    c1 = len(data[strong_series & (frame['Opp-Status'].str.match(opp_status))])
    a1 = len(data)
    print('numerator :    ', c1)
    print('denumerator : ', a1)
    print('output: ', c1/a1)
    return c1/a1

# %%
def count_win(data, aval=False, strong=False, opp_status=None):
    aval_series = data['Aval'] if aval else data['Aval'] == False
    strong_series = data['Strong'] if strong else data['Strong'] == False
    win = len(data[(data['W/L'].str.contains("W")) & aval_series & strong_series & (frame['Opp-Status'].str.match(opp_status))])
    number_of_all_games =  len(data[aval_series & strong_series & (frame['Opp-Status'].str.match(opp_status))])
    print('numerator :    ', win)
    print('denumerator : ', number_of_all_games)
    if number_of_all_games == 0:
        print('output: ', 0)
        return 0
    else: 
        print('output: ', win/number_of_all_games)
        return win/number_of_all_games

# %%
def get_WAR(data = frame):
    
    print('P_Aval_Weak_weakOpp :')
    aval_weak_weak = count_win(data, aval = True, strong = False, opp_status="Weak") 
    print('P_Unaval_Weak_weakOpp :')
    unaval_weal_weak = count_win(data, aval = False, strong = False, opp_status="Weak")
    print('P X = Weak_weakOpp :')
    weak_weak = count_category(data, strong = False, opp_status="Weak")
    
    print('P_Aval_Weak_averageOpp :')
    aval_weak_average = count_win(data, aval = True, strong = False, opp_status="Average")
    print('P_Unaval_Weak_averageOpp :')
    unaval_weak_average = count_win(data, aval = False, strong = False, opp_status="Average")
    print('P X = Weak_averageOpp :')
    weak_average = count_category(data, strong = False, opp_status="Average")
    
    print('P_Aval_Weak_strongOpp :')
    aval_weak_strong = count_win(data, aval = True, strong = False, opp_status="Strong")
    print('P_Unaval_Weak_strongOpp :')
    unaval_weak_strong = count_win(data, aval = False, strong = False, opp_status="Strong")
    print('P X = Weak_strongOpp :')
    weak_strong = count_category(data, strong = False, opp_status="Strong")
    
    print('P_Aval_Strong_weakOpp :')
    aval_strong_weak = count_win(data, aval = True, strong = True, opp_status="Weak") 
    print('P_Unaval_Strong_weakOpp :')
    unaval_strong_weak = count_win(data, aval = False, strong = True, opp_status="Weak")
    print('P X = Strong_weakOpp :')
    strong_weak = count_category(data, strong = True, opp_status="Weak")
    
    print('P_Aval_Strong_averageOpp :')
    aval_strong_average = count_win(data, aval = True, strong = True, opp_status="Average")
    print('P_Unaval_Strong_averageOpp :')
    unaval_strong_average = count_win(data, aval = False, strong = True, opp_status="Average")
    print('P X = Strong_averageOpp :')
    strong_average = count_category(data, strong = True, opp_status="Average")
    
    print('P_Aval_Strong_strongOpp :')
    aval_strong_strong = count_win(data, aval = True, strong = True, opp_status="Strong")
    print('P_Unaval_Strong_strongOpp :')
    unaval_strong_strong = count_win(data, aval = False, strong = True, opp_status="Strong")
    print('P X = Strong_strongOpp :')
    strong_strong = count_category(data, strong = True, opp_status="Strong")
    
    war = ((aval_weak_weak - unaval_weal_weak)* weak_weak
           + (aval_weak_average - unaval_weak_average)* weak_average
           + (aval_weak_strong - unaval_weak_strong)* weak_strong 
           + (aval_strong_weak - unaval_strong_weak)* strong_weak
           + (aval_strong_average - unaval_strong_average)* strong_average 
           + (aval_strong_strong - unaval_strong_strong)* strong_strong) * 119
    return war

# %%
get_WAR()
# Out:
# P_Aval_Weak_weakOpp :
# numerator :     23
# denumerator :  46
# output:  0.5
# P_Unaval_Weak_weakOpp :
# numerator :     3
# denumerator :  7
# output:  0.42857142857142855
# P X = Weak_weakOpp :
# numerator :     53
# denumerator :  161
# output:  0.32919254658385094
# P_Aval_Weak_averageOpp :
# numerator :     17
# denumerator :  40
# output:  0.425
# P_Unaval_Weak_averageOpp :
# numerator :     0
# denumerator :  0
# output:  0
# P X = Weak_averageOpp :
# numerator :     40
# denumerator :  161
# output:  0.2484472049689441
# P_Aval_Weak_strongOpp :
# numerator :     13
# denumerator :  26
# output:  0.5
# P_Unaval_Weak_strongOpp :
# numerator :     3
# denumerator :  6
# output:  0.5
# P X = Weak_strongOpp :
# numerator :     32
# denumerator :  161
# output:  0.19875776397515527
# P_Aval_Strong_weakOpp :
# numerator :     4
# denumerator :  7
# output:  0.5714285714285714
# P_Unaval_Strong_weakOpp :
# numerator :     7
# denumerator :  16
# output:  0.4375
# P X = Strong_weakOpp :
# numerator :     23
# denumerator :  161
# output:  0.14285714285714285
# P_Aval_Strong_averageOpp :
# numerator :     1
# denumerator :  3
# output:  0.3333333333333333
# P_Unaval_Strong_averageOpp :
# numerator :     1
# denumerator :  4
# output:  0.25
# P X = Strong_averageOpp :
# numerator :     7
# denumerator :  161
# output:  0.043478260869565216
# P_Aval_Strong_strongOpp :
# numerator :     1
# denumerator :  4
# output:  0.25
# P_Unaval_Strong_strongOpp :
# numerator :     1
# denumerator :  2
# output:  0.5
# P X = Strong_strongOpp :
# numerator :     6
# denumerator :  161
# output:  0.037267080745341616
# 16.962603519668736
